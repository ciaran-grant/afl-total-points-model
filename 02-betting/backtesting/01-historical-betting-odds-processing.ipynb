# %% [markdown]
# Process historical betting odds from AFL Repository (aussportsbetting.com)

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
odds = pd.read_csv("/total-points-score-model/data/aus_sports_betting_odds.csv")

# %%
odds.head()
# Out:
#    Unnamed: 0       Home_Team    Away_Team        Date  Home_Odds  Away_Odds  \
# 0           1        Essendon    Melbourne  2009-06-19       1.24       3.93
# 1           2       Fremantle      Geelong  2009-06-21       7.25       1.08
# 2           3          Sydney  Collingwood  2009-06-20       1.93       1.75
# 3           4        Adelaide       Sydney  2009-06-27       1.25       3.75
# 4           5  Brisbane Lions    Melbourne  2009-06-27       1.06       8.25
#
#    Bookmakers_Surveyed  Home_Odds_Open  Home_Odds_Min  Home_Odds_Max  ...  \
# 0                    5             NaN            NaN            NaN  ...
# 1                    5             NaN            NaN            NaN  ...
# 2                    5             NaN            NaN            NaN  ...
# 3                    5             NaN            NaN            NaN  ...
# 4                    5             NaN            NaN            NaN  ...
#
#    Total_Score_Over_Min  Total_Score_Over_Max  Total_Score_Over_Close  \
# 0                   NaN                   NaN                     NaN
# 1                   NaN                   NaN                     NaN
# 2                   NaN                   NaN                     NaN
# 3                   NaN                   NaN                     NaN
# 4                   NaN                   NaN                     NaN
#
#    Total_Score_Under_Open  Total_Score_Under_Min  Total_Score_Under_Max  \
# 0                     NaN                    NaN                    NaN
# 1                     NaN                    NaN                    NaN
# 2                     NaN                    NaN                    NaN
# 3                     NaN                    NaN                    NaN
# 4                     NaN                    NaN                    NaN
#
#    Total_Score_Under_Close                        Match_ID  Round_ID  Season
# 0                      NaN       200912_Essendon_Melbourne    200912    2009
# 1                      NaN        200912_Fremantle_Geelong    200912    2009
# 2                      NaN       200912_Sydney_Collingwood    200912    2009
# 3                      NaN          200913_Adelaide_Sydney    200913    2009
# 4                      NaN  200913_BrisbaneLions_Melbourne    200913    2009
#
# [5 rows x 46 columns]

# %%
odds = odds[odds['Date'] > "2019-01-01"]

# %%
list(odds)
# Out:
# ['Unnamed: 0',
#  'Home_Team',
#  'Away_Team',
#  'Date',
#  'Home_Odds',
#  'Away_Odds',
#  'Bookmakers_Surveyed',
#  'Home_Odds_Open',
#  'Home_Odds_Min',
#  'Home_Odds_Max',
#  'Home_Odds_Close',
#  'Away_Odds_Open',
#  'Away_Odds_Min',
#  'Away_Odds_Max',
#  'Away_Odds_Close',
#  'Home_Line_Open',
#  'Home_Line_Min',
#  'Home_Line_Max',
#  'Home_Line_Close',
#  'Away_Line_Open',
#  'Away_Line_Min',
#  'Away_Line_Max',
#  'Away_Line_Close',
#  'Home_Line_Odds_Open',
#  'Home_Line_Odds_Min',
#  'Home_Line_Odds_Max',
#  'Home_Line_Odds_Close',
#  'Away_Line_Odds_Open',
#  'Away_Line_Odds_Min',
#  'Away_Line_Odds_Max',
#  'Away_Line_Odds_Close',
#  'Total_Score_Open',
#  'Total_Score_Min',
#  'Total_Score_Max',
#  'Total_Score_Close',
#  'Total_Score_Over_Open',
#  'Total_Score_Over_Min',
#  'Total_Score_Over_Max',
#  'Total_Score_Over_Close',
#  'Total_Score_Under_Open',
#  'Total_Score_Under_Min',
#  'Total_Score_Under_Max',
#  'Total_Score_Under_Close',
#  'Match_ID',
#  'Round_ID',
#  'Season']

# %%
total_score_odds_cols = [
    'Match_ID',
    'Round_ID',
    'Season',
    'Home_Team',
    'Away_Team',
    'Total_Score_Open',
    'Total_Score_Over_Open',
    'Total_Score_Over_Close',
    'Total_Score_Close',
    'Total_Score_Under_Open',
    'Total_Score_Under_Close'
    ]

# %%
total_score_odds = odds[total_score_odds_cols]

# %%
total_score_odds.head()
# Out:
#                              Match_ID Round_ID  Season       Home_Team  \
# 1922         201901_Adelaide_Hawthorn   201901    2019        Adelaide
# 1923   201901_BrisbaneLions_WestCoast   201901    2019  Brisbane Lions
# 1924          201901_Carlton_Richmond   201901    2019         Carlton
# 1925       201901_Collingwood_Geelong   201901    2019     Collingwood
# 1926  201901_Fremantle_NorthMelbourne   201901    2019       Fremantle
#
#             Away_Team  Total_Score_Open  Total_Score_Over_Open  \
# 1922         Hawthorn               NaN                    NaN
# 1923       West Coast               NaN                    NaN
# 1924         Richmond               NaN                    NaN
# 1925          Geelong               NaN                    NaN
# 1926  North Melbourne               NaN                    NaN
#
#       Total_Score_Over_Close  Total_Score_Close  Total_Score_Under_Open  \
# 1922                    1.91              185.5                     NaN
# 1923                    1.91              186.5                     NaN
# 1924                    1.91              188.5                     NaN
# 1925                    1.91              181.5                     NaN
# 1926                    1.91              176.5                     NaN
#
#       Total_Score_Under_Close
# 1922                     1.91
# 1923                     1.91
# 1924                     1.91
# 1925                     1.91
# 1926                     1.91

# %% [markdown]
# Separate Over/Under into separate rows

# %%
ordered_cols = [
    'Match_ID',
    'Round_ID',
    'Season',
    'Home_Team',
    'Away_Team',
    'Market',
    'Total_Score_Open',
    'Total_Score_Close',
    'Total_Score_Open_Odds',
    'Total_Score_Close_Odds',
    ]

# %%
total_score_under = total_score_odds.drop(columns = ['Total_Score_Over_Open', 'Total_Score_Over_Close'])
total_score_under = total_score_under.rename(columns = {'Total_Score_Under_Open':'Total_Score_Open_Odds',
                                                        'Total_Score_Under_Close':'Total_Score_Close_Odds'})
total_score_under['Market'] = "Under"
total_score_under = total_score_under[ordered_cols]
total_score_under.head()
# Out:
#                              Match_ID Round_ID  Season       Home_Team  \
# 1922         201901_Adelaide_Hawthorn   201901    2019        Adelaide
# 1923   201901_BrisbaneLions_WestCoast   201901    2019  Brisbane Lions
# 1924          201901_Carlton_Richmond   201901    2019         Carlton
# 1925       201901_Collingwood_Geelong   201901    2019     Collingwood
# 1926  201901_Fremantle_NorthMelbourne   201901    2019       Fremantle
#
#             Away_Team Market  Total_Score_Open  Total_Score_Close  \
# 1922         Hawthorn  Under               NaN              185.5
# 1923       West Coast  Under               NaN              186.5
# 1924         Richmond  Under               NaN              188.5
# 1925          Geelong  Under               NaN              181.5
# 1926  North Melbourne  Under               NaN              176.5
#
#       Total_Score_Open_Odds  Total_Score_Close_Odds
# 1922                    NaN                    1.91
# 1923                    NaN                    1.91
# 1924                    NaN                    1.91
# 1925                    NaN                    1.91
# 1926                    NaN                    1.91

# %%
total_score_over = total_score_odds.drop(columns = ['Total_Score_Under_Open', 'Total_Score_Under_Close'])
total_score_over = total_score_over.rename(columns = {'Total_Score_Over_Open':'Total_Score_Open_Odds',
                                                        'Total_Score_Over_Close':'Total_Score_Close_Odds'})
total_score_over['Market'] = "Over"
total_score_over = total_score_over[ordered_cols]
total_score_over.head()
# Out:
#                              Match_ID Round_ID  Season       Home_Team  \
# 1922         201901_Adelaide_Hawthorn   201901    2019        Adelaide
# 1923   201901_BrisbaneLions_WestCoast   201901    2019  Brisbane Lions
# 1924          201901_Carlton_Richmond   201901    2019         Carlton
# 1925       201901_Collingwood_Geelong   201901    2019     Collingwood
# 1926  201901_Fremantle_NorthMelbourne   201901    2019       Fremantle
#
#             Away_Team Market  Total_Score_Open  Total_Score_Close  \
# 1922         Hawthorn   Over               NaN              185.5
# 1923       West Coast   Over               NaN              186.5
# 1924         Richmond   Over               NaN              188.5
# 1925          Geelong   Over               NaN              181.5
# 1926  North Melbourne   Over               NaN              176.5
#
#       Total_Score_Open_Odds  Total_Score_Close_Odds
# 1922                    NaN                    1.91
# 1923                    NaN                    1.91
# 1924                    NaN                    1.91
# 1925                    NaN                    1.91
# 1926                    NaN                    1.91

# %% [markdown]
# Combine Over/Under

# %%
total_score_data = pd.concat([total_score_over, total_score_under])
total_score_data = total_score_data.sort_values(by = ['Match_ID'])

# %%
total_score_data.head()
# Out:
#                             Match_ID Round_ID  Season       Home_Team  \
# 1922        201901_Adelaide_Hawthorn   201901    2019        Adelaide
# 1922        201901_Adelaide_Hawthorn   201901    2019        Adelaide
# 1923  201901_BrisbaneLions_WestCoast   201901    2019  Brisbane Lions
# 1923  201901_BrisbaneLions_WestCoast   201901    2019  Brisbane Lions
# 1924         201901_Carlton_Richmond   201901    2019         Carlton
#
#        Away_Team Market  Total_Score_Open  Total_Score_Close  \
# 1922    Hawthorn   Over               NaN              185.5
# 1922    Hawthorn  Under               NaN              185.5
# 1923  West Coast   Over               NaN              186.5
# 1923  West Coast  Under               NaN              186.5
# 1924    Richmond   Over               NaN              188.5
#
#       Total_Score_Open_Odds  Total_Score_Close_Odds
# 1922                    NaN                    1.91
# 1922                    NaN                    1.91
# 1923                    NaN                    1.91
# 1923                    NaN                    1.91
# 1924                    NaN                    1.91

# %% [markdown]
# Calculate Implied and True Odds Probabilities

# %%
def convert_decimal_odds_to_probability(decimal_odds):
    
    return 1 / decimal_odds

# %%
total_score_data['Total_Score_Open_Implied%'] = convert_decimal_odds_to_probability(total_score_data['Total_Score_Open_Odds'])
total_score_data['Total_Score_Close_Implied%'] = convert_decimal_odds_to_probability(total_score_data['Total_Score_Close_Odds'])

# %%
total_score_data.head()
# Out:
#                             Match_ID Round_ID  Season       Home_Team  \
# 1922        201901_Adelaide_Hawthorn   201901    2019        Adelaide
# 1922        201901_Adelaide_Hawthorn   201901    2019        Adelaide
# 1923  201901_BrisbaneLions_WestCoast   201901    2019  Brisbane Lions
# 1923  201901_BrisbaneLions_WestCoast   201901    2019  Brisbane Lions
# 1924         201901_Carlton_Richmond   201901    2019         Carlton
#
#        Away_Team Market  Total_Score_Open  Total_Score_Close  \
# 1922    Hawthorn   Over               NaN              185.5
# 1922    Hawthorn  Under               NaN              185.5
# 1923  West Coast   Over               NaN              186.5
# 1923  West Coast  Under               NaN              186.5
# 1924    Richmond   Over               NaN              188.5
#
#       Total_Score_Open_Odds  Total_Score_Close_Odds  \
# 1922                    NaN                    1.91
# 1922                    NaN                    1.91
# 1923                    NaN                    1.91
# 1923                    NaN                    1.91
# 1924                    NaN                    1.91
#
#       Total_Score_Close_Implied%  Total_Score_Open_Implied%
# 1922                     0.52356                        NaN
# 1922                     0.52356                        NaN
# 1923                     0.52356                        NaN
# 1923                     0.52356                        NaN
# 1924                     0.52356                        NaN

# %%
total_implied_odds = total_score_data[['Match_ID', 'Total_Score_Open_Implied%', 'Total_Score_Close_Implied%']].groupby(['Match_ID']).sum().reset_index()
total_implied_odds.columns = ["Match_ID", "Total_Score_Open_Total%", "Total_Score_Close_Total%"]
total_implied_odds.head()
# Out:
#                           Match_ID  Total_Score_Open_Total%  \
# 0         201901_Adelaide_Hawthorn                      0.0
# 1   201901_BrisbaneLions_WestCoast                      0.0
# 2          201901_Carlton_Richmond                      0.0
# 3       201901_Collingwood_Geelong                      0.0
# 4  201901_Fremantle_NorthMelbourne                      0.0
#
#    Total_Score_Close_Total%
# 0                   1.04712
# 1                   1.04712
# 2                   1.04712
# 3                   1.04712
# 4                   1.04712

# %%
total_score_data = pd.merge(total_score_data, total_implied_odds, how = "left", on = "Match_ID")

# %%
total_score_data['Total_Score_Open_Margin'] = np.where(total_score_data['Total_Score_Open_Total%'] == 0.0, 0, total_score_data['Total_Score_Open_Total%'] - 1)
total_score_data['Total_Score_Close_Margin'] = np.where(total_score_data['Total_Score_Close_Total%'] == 0.0, 0, total_score_data['Total_Score_Close_Total%'] - 1)

# %%
total_score_data.head()
# Out:
#                          Match_ID Round_ID  Season       Home_Team  \
# 0        201901_Adelaide_Hawthorn   201901    2019        Adelaide
# 1        201901_Adelaide_Hawthorn   201901    2019        Adelaide
# 2  201901_BrisbaneLions_WestCoast   201901    2019  Brisbane Lions
# 3  201901_BrisbaneLions_WestCoast   201901    2019  Brisbane Lions
# 4         201901_Carlton_Richmond   201901    2019         Carlton
#
#     Away_Team Market  Total_Score_Open  Total_Score_Close  \
# 0    Hawthorn   Over               NaN              185.5
# 1    Hawthorn  Under               NaN              185.5
# 2  West Coast   Over               NaN              186.5
# 3  West Coast  Under               NaN              186.5
# 4    Richmond   Over               NaN              188.5
#
#    Total_Score_Open_Odds  Total_Score_Close_Odds  Total_Score_Close_Implied%  \
# 0                    NaN                    1.91                     0.52356
# 1                    NaN                    1.91                     0.52356
# 2                    NaN                    1.91                     0.52356
# 3                    NaN                    1.91                     0.52356
# 4                    NaN                    1.91                     0.52356
#
#    Total_Score_Open_Implied%  Total_Score_Open_Total%  \
# 0                        NaN                      0.0
# 1                        NaN                      0.0
# 2                        NaN                      0.0
# 3                        NaN                      0.0
# 4                        NaN                      0.0
#
#    Total_Score_Close_Total%  Total_Score_Open_Margin  Total_Score_Close_Margin
# 0                   1.04712                      0.0                   0.04712
# 1                   1.04712                      0.0                   0.04712
# 2                   1.04712                      0.0                   0.04712
# 3                   1.04712                      0.0                   0.04712
# 4                   1.04712                      0.0                   0.04712

# %%
total_score_data['Total_Score_Open_True%'] = total_score_data['Total_Score_Open_Implied%'] / total_score_data['Total_Score_Open_Total%']
total_score_data['Total_Score_Close_True%'] = total_score_data['Total_Score_Close_Implied%'] / total_score_data['Total_Score_Close_Total%']

# %%
total_score_data.head()
# Out:
#                          Match_ID Round_ID  Season       Home_Team  \
# 0        201901_Adelaide_Hawthorn   201901    2019        Adelaide
# 1        201901_Adelaide_Hawthorn   201901    2019        Adelaide
# 2  201901_BrisbaneLions_WestCoast   201901    2019  Brisbane Lions
# 3  201901_BrisbaneLions_WestCoast   201901    2019  Brisbane Lions
# 4         201901_Carlton_Richmond   201901    2019         Carlton
#
#     Away_Team Market  Total_Score_Open  Total_Score_Close  \
# 0    Hawthorn   Over               NaN              185.5
# 1    Hawthorn  Under               NaN              185.5
# 2  West Coast   Over               NaN              186.5
# 3  West Coast  Under               NaN              186.5
# 4    Richmond   Over               NaN              188.5
#
#    Total_Score_Open_Odds  Total_Score_Close_Odds  Total_Score_Close_Implied%  \
# 0                    NaN                    1.91                     0.52356
# 1                    NaN                    1.91                     0.52356
# 2                    NaN                    1.91                     0.52356
# 3                    NaN                    1.91                     0.52356
# 4                    NaN                    1.91                     0.52356
#
#    Total_Score_Open_Implied%  Total_Score_Open_Total%  \
# 0                        NaN                      0.0
# 1                        NaN                      0.0
# 2                        NaN                      0.0
# 3                        NaN                      0.0
# 4                        NaN                      0.0
#
#    Total_Score_Close_Total%  Total_Score_Open_Margin  \
# 0                   1.04712                      0.0
# 1                   1.04712                      0.0
# 2                   1.04712                      0.0
# 3                   1.04712                      0.0
# 4                   1.04712                      0.0
#
#    Total_Score_Close_Margin  Total_Score_Open_True%  Total_Score_Close_True%
# 0                   0.04712                     NaN                      0.5
# 1                   0.04712                     NaN                      0.5
# 2                   0.04712                     NaN                      0.5
# 3                   0.04712                     NaN                      0.5
# 4                   0.04712                     NaN                      0.5

# %%
def convert_probability_to_decimal_odds(prob):
    
    return round(1 / (prob / 1), 2)

# %%
total_score_data['Total_Score_Open_True_Odds'] = convert_probability_to_decimal_odds(total_score_data['Total_Score_Open_True%'])
total_score_data['Total_Score_Close_True_Odds'] = convert_probability_to_decimal_odds(total_score_data['Total_Score_Close_True%'])

# %%
total_score_data.tail()
# Out:
#                           Match_ID Round_ID  Season Home_Team       Away_Team  \
# 1561  2022F3_Geelong_BrisbaneLions   2022F3    2022   Geelong  Brisbane Lions
# 1562     2022F3_Sydney_Collingwood   2022F3    2022    Sydney     Collingwood
# 1563     2022F3_Sydney_Collingwood   2022F3    2022    Sydney     Collingwood
# 1564         2022F4_Geelong_Sydney   2022F4    2022   Geelong          Sydney
# 1565         2022F4_Geelong_Sydney   2022F4    2022   Geelong          Sydney
#
#      Market  Total_Score_Open  Total_Score_Close  Total_Score_Open_Odds  \
# 1561   Over             160.5              159.5                   1.91
# 1562  Under             160.5              162.5                   1.91
# 1563   Over             160.5              162.5                   1.91
# 1564   Over             163.5              164.5                   1.91
# 1565  Under             163.5              164.5                   1.91
#
#       Total_Score_Close_Odds  Total_Score_Close_Implied%  \
# 1561                    1.91                     0.52356
# 1562                    1.91                     0.52356
# 1563                    1.91                     0.52356
# 1564                    1.91                     0.52356
# 1565                    1.91                     0.52356
#
#       Total_Score_Open_Implied%  Total_Score_Open_Total%  \
# 1561                    0.52356                  1.04712
# 1562                    0.52356                  1.04712
# 1563                    0.52356                  1.04712
# 1564                    0.52356                  1.04712
# 1565                    0.52356                  1.04712
#
#       Total_Score_Close_Total%  Total_Score_Open_Margin  \
# 1561                   1.04712                  0.04712
# 1562                   1.04712                  0.04712
# 1563                   1.04712                  0.04712
# 1564                   1.04712                  0.04712
# 1565                   1.04712                  0.04712
#
#       Total_Score_Close_Margin  Total_Score_Open_True%  \
# 1561                   0.04712                     0.5
# 1562                   0.04712                     0.5
# 1563                   0.04712                     0.5
# 1564                   0.04712                     0.5
# 1565                   0.04712                     0.5
#
#       Total_Score_Close_True%  Total_Score_Open_True_Odds  \
# 1561                      0.5                         2.0
# 1562                      0.5                         2.0
# 1563                      0.5                         2.0
# 1564                      0.5                         2.0
# 1565                      0.5                         2.0
#
#       Total_Score_Close_True_Odds
# 1561                          2.0
# 1562                          2.0
# 1563                          2.0
# 1564                          2.0
# 1565                          2.0

# %%
total_score_data.mean()
# Out:
# Season                         2020.528736
# Total_Score_Open                155.200258
# Total_Score_Close               154.281609
# Total_Score_Open_Odds             1.896938
# Total_Score_Close_Odds            1.909642
# Total_Score_Close_Implied%        0.523684
# Total_Score_Open_Implied%         0.527185
# Total_Score_Open_Total%           1.042251
# Total_Score_Close_Total%          1.047368
# Total_Score_Open_Margin           0.053745
# Total_Score_Close_Margin          0.047368
# Total_Score_Open_True%            0.500000
# Total_Score_Close_True%           0.500000
# Total_Score_Open_True_Odds        2.000006
# Total_Score_Close_True_Odds       2.000038
# dtype: float64

# %% [markdown]
# Export to csv

# %%
list(total_score_data)
# Out:
# ['Match_ID',
#  'Round_ID',
#  'Season',
#  'Home_Team',
#  'Away_Team',
#  'Market',
#  'Total_Score_Open',
#  'Total_Score_Close',
#  'Total_Score_Open_Odds',
#  'Total_Score_Close_Odds',
#  'Total_Score_Close_Implied%',
#  'Total_Score_Open_Implied%',
#  'Total_Score_Open_Total%',
#  'Total_Score_Close_Total%',
#  'Total_Score_Open_Margin',
#  'Total_Score_Close_Margin',
#  'Total_Score_Open_True%',
#  'Total_Score_Close_True%',
#  'Total_Score_Open_True_Odds',
#  'Total_Score_Close_True_Odds']

# %%
export_cols = [
    'Match_ID',
    'Round_ID',
    'Season',
    'Home_Team',
    'Away_Team',
    'Market',
    'Total_Score_Open',
    'Total_Score_Close',
    'Total_Score_Open_Odds',
    'Total_Score_Close_Odds',
    'Total_Score_Close_Implied%',
    'Total_Score_Open_Implied%',
    'Total_Score_Open_Total%',
    'Total_Score_Close_Total%',
    'Total_Score_Open_Margin',
    'Total_Score_Close_Margin',
    'Total_Score_Open_True%',
    'Total_Score_Close_True%',
    'Total_Score_Open_True_Odds',
    'Total_Score_Close_True_Odds'
]

# %%
total_score_data.to_csv("/total-points-score-model/data/aus_sports_betting_total_score_odds.csv", index = False)
